# %% [markdown]
# # Day 2: Chunking
#
# Today we are going to explore the types of chunking.

# %%
#Let's add the markdown download code here
import io
import zipfile
import requests
import frontmatter

def read_repo_data(repo_owner, repo_name):
    """
    Download and parse all markdown files from a GitHub repository.

    Args:
        repo_owner: GitHub username or organization
        repo_name: Repository name

    Returns:
        List of dictionaries containing file content and metadata
    """
    prefix = 'https://codeload.github.com'
    url = f'{prefix}/{repo_owner}/{repo_name}/zip/refs/heads/main'
    resp = requests.get(url)

    if resp.status_code != 200:
        raise Exception(f"Failed to download repository: {resp.status_code}")

    repository_data = []
    zf = zipfile.ZipFile(io.BytesIO(resp.content))

    for file_info in zf.infolist():
        filename = file_info.filename
        filename_lower = filename.lower()

        if not (filename_lower.endswith('.md')
            or filename_lower.endswith('.mdx')):
            continue

        try:
            with zf.open(file_info) as f_in:
                content = f_in.read().decode('utf-8', errors='ignore')
                post = frontmatter.loads(content)
                data = post.to_dict()
                data['filename'] = filename
                repository_data.append(data)
        except Exception as e:
            print(f"Error processing {filename}: {e}")
            continue

    zf.close()
    return repository_data

# %%
print("Hello from course!")
balsam_faq = read_repo_data('Zesky665', 'balsam')
evidently_docs = read_repo_data('evidentlyai', 'docs')
    
print(f"FAQ documents: {len(balsam_faq)}")
print(f"Evidently documents: {len(evidently_docs)}")
# Out:
# Hello from course!
# FAQ documents: 3
# Evidently documents: 95

# %%
# Now we can start chunking
# There are multiple ways of chunking a document.
# Here they are in order of complexity:
# - Simple Chunking
# - Token Based Chunking
# - Sematinc Chunking
# - Paragrapgh Splitting
# - Section Splitting
# - AI-powered Splitting

# %%
# The most commonly used simple chunking method is sliding window, which is chunking with overlap.
def sliding_window(seq, size, step):
    if size <= 0 or step <= 0:
        raise ValueError("size and step must be positive")

    n = len(seq)
    result = []
    for i in range(0, n, step):
        chunk = seq[i:i+size]
        result.append({'start': i, 'chunk': chunk})
        if i + size >= n:
            break

    return result

# %%
evidently_chunks = []

for doc in evidently_docs:
    doc_copy = doc.copy()
    doc_content = doc_copy['content']
    chunks = sliding_window(doc_content, 2000, 1000)
    for chunk in chunks:
        chunk.update(doc_copy)
    evidently_chunks.extend(chunks)

# %%
# Section Splitting
import re
text = evidently_docs[45]['content']
paragraphs = re.split(r"\n\s*\n", text.strip())

# %%
import re

def split_markdown_by_level(text, level=2):
    """
    Split markdown text by a specific header level.

    :param text: Markdown text as a string
    :param level: Header level to split on
    :return: List of sections as strings
    """
    # This regex matches markdown headers
    # For level 2, it matches lines starting with "## "
    header_pattern = r'^(#{' + str(level) + r'} )(.+)$'
    pattern = re.compile(header_pattern, re.MULTILINE)

    # Split and keep the headers
    parts = pattern.split(text)

    sections = []
    for i in range(1, len(parts), 3):
        # We step by 3 because regex.split() with
        # capturing groups returns:
        # [before_match, group1, group2, after_match, ...]
        # here group1 is "## ", group2 is the header text
        header = parts[i] + parts[i+1]  # "## " + "Title"
        header = header.strip()

        # Get the content after this header
        content = ""
        if i+2 < len(parts):
            content = parts[i+2].strip()

        if content:
            section = f'{header}\n\n{content}'
        else:
            section = header
        sections.append(section)

    return sections

# %%
evidently_chunks = []

for doc in evidently_docs:
    doc_copy = doc.copy()
    doc_content = doc_copy.pop('content')
    sections = split_markdown_by_level(doc_content, level=2)
    for section in sections:
        section_doc = doc_copy.copy()
        section_doc['section'] = section
        evidently_chunks.append(section_doc)

# %%
# LLM Based Chunking
import os
from mistralai import Mistral

api_key=os.environ["MISTRAL_API_KEY"]
model = "mistral-large-latest"

client = Mistral(api_key=api_key)

def llm(prompt, model="mistral-large-latest"):
    chat_response = client.chat.complete(
        model= model,
        messages = [
            {
                "role": "user",
                "content": "What is the best French cheese?",
            },
        ]
    )
    print(chat_response.choices[0].message.content)
    return chat_response.choices[0].message.content

# %%
prompt_template = """
Split the provided document into logical sections
that make sense for a Q&A system.

Each section should be self-contained and cover
a specific topic or concept.

<DOCUMENT>
{document}
</DOCUMENT>

Use this format:

## Section Name

Section content with all relevant details

---

## Another Section Name

Another section content

---
""".strip()

# %%
def intelligent_chunking(text):
    prompt = prompt_template.format(document=text)
    response = llm(prompt_template)
    sections = response.split('---')
    sections = [s.strip() for s in sections if s.strip()]
    return sections

# %%
from tqdm.auto import tqdm

evidently_chunks = []

for doc in tqdm(evidently_docs):
    doc_copy = doc.copy()
    doc_content = doc_copy.pop('content')

    sections = intelligent_chunking(doc_content)
    for section in sections:
        section_doc = doc_copy.copy()
        section_doc['section'] = section
        evidently_chunks.append(section_doc)
# Out:
#   0%|          | 0/95 [00:00<?, ?it/s]
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most **iconic, award-winning, and beloved French cheeses**, each celebrated for its unique qualities:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté (AOP)** – *The King of Alpine Cheeses*
#    - **Why?** Aged 4 to 36+ months, Comté offers a perfect balance of nutty, caramelized, and fruity flavors. It’s versatile (great for melting, snacking, or grating) and consistently excellent.
#    - **Best for:** Fondue, gratins, charcuterie boards.
#    - **Fun fact:** Each wheel is unique due to variations in terroir and aging.
#
# 2. **Roquefort (AOP)** – *The Legendary Blue*
#    - **Why?** Made from **raw sheep’s milk** and aged in the natural caves of Roquefort-sur-Soulzon, it’s creamy, tangy, and intensely flavorful with a perfect salt-crystal crunch.
#    - **Best for:** Salads (like with pears or walnuts), sauces, or spread on bread.
#    - **Fun fact:** Charlemagne reportedly loved it—it’s one of the oldest named cheeses in the world (since 1070).
#
# 3. **Époisses (AOP)** – *The Stinky Superstar*
#    - **Why?** Washed in **Marc de Bourgogne** (a local brandy), this **pungent, runny, and decadent** cow’s milk cheese is famously banned from French public transport due to its smell. Napoleon adored it.
#    - **Best for:** Spreading on crusty bread with a spoon (it’s that soft).
#    - **Fun fact:** It was once called *"the king of cheeses"* by Brillat-Savarin.
#
# 4. **Camembert de Normandie (AOP)** – *The Classic*
#    - **Why?** The **original Camembert** (not the industrial versions) is buttery, earthy, and slightly mushroomy with a **creamy, oozing center**. Best when perfectly ripe.
#    - **Best for:** Baked (Camembert en croûte), with apples or honey.
#    - **Fun fact:** It became a symbol of French resistance in WWII—soldiers were given it in rations.
#
# 5. **Reblochon (AOP)** – *The Melting Master*
#    - **Why?** The **star of Tartiflette** (a baked potato, bacon, and cheese dish), this **washed-rind** cheese is **creamy, nutty, and slightly smoky**.
#    - **Best for:** Melting (Tartiflette, croque-monsieur), or on a cheese board with cured meats.
#    - **Fun fact:** Its name comes from *"re-blocher"* (to "re-milk" cows partially).
#
# 6. **Brie de Meaux (AOP)** – *The "Queen of Cheeses"*
#    - **Why?** Larger and more complex than standard Brie, with **earthy, truffle-like notes** and a **velvety texture**. Louis XIV and Talleyrand were fans.
#    - **Best for:** Pairing with Champagne, on a baguette, or baked.
#    - **Fun fact:** It was served at the **Congress of Vienna (1815)** as a diplomatic peace offering.
#
# 7. **Munster (AOP)** – *The Alsatian Powerhouse*
#    - **Why?** A **strong, pungent washed-rind** cheese with a **creamy, almost meaty** flavor. Often served with **cumin seeds**.
#    - **Best for:** Melting (in tarts or on potatoes), or with Gewürztraminer wine.
#    - **Fun fact:** Monks originally made it—hence the name (from "monastère").
#
# 8. **Pélardon (AOP)** – *The Goat Cheese Gem*
#    - **Why?** A **small, tangy, and slightly nutty** goat cheese from the Cévennes or Provence. Comes in **ash-coated or natural rind** varieties.
#    - **Best for:** Salads, grilling, or spreading on toast.
#    - **Fun fact:** It’s one of the oldest French cheeses, dating back to **Roman times**.
#
# 9. **Beaufort (AOP)** – *The Alpine Giant*
#    - **Why?** A **firm, buttery, and slightly sweet** cow’s milk cheese, often called **"the prince of Gruyères."** Aged versions develop **caramel and hazelnut notes**.
#    - **Best for:** Fondue, gratins, or shaving over salads.
#    - **Fun fact:** It’s made in **copper vat** for a unique texture.
#
# 10. **Banon (AOP)** – *The Wrapped Treasure*
#    - **Why?** A **creamy, mild goat cheese** wrapped in **chestnut leaves** and tied with raffia. The leaves infuse it with a **subtle woody aroma**.
#    - **Best for:** Picnics, with figs or honey.
#    - **Fun fact:** It was traditionally carried by **shepherds** in Provence.
#
# ### **Honorable Mentions**
# - **Saint-Nectaire** (AOP) – Earthy, buttery, great for cooking.
# - **Crottin de Chavignol** (AOP) – A **dry, tangy goat cheese**, perfect grilled.
# - **Mimolette** – A **vibrant orange**, nutty hard cheese (like a French cheddar).
# - **Tomme de Savoie** – A **semi-hard, fruity** mountain cheese.
# - **Chaource** (AOP) – A **creamy, mild** cow’s milk cheese, similar to Brie but richer.
#
# ### **How to Choose?**
# - **For beginners:** Comté, Brie de Meaux, or Saint-Nectaire (mild and approachable).
# - **For adventurous eaters:** Époisses, Munster, or Roquefort (strong flavors).
# - **For melting:** Reblochon, Beaufort, or Comté.
# - **For goat cheese lovers:** Pélardon, Crottin, or Banon.
#
# ### **Final Verdict?**
# If forced to pick **one "best"**, **Comté** (for its versatility and depth) or **Roquefort** (for its bold, historic excellence) would be top contenders. But the true answer is: **try them all!**
#
# Would you like recommendations based on a specific dish or wine pairing?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most celebrated and iconic French cheeses, each with its own unique appeal:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Why?** A versatile, nutty, and slightly sweet Alpine cheese with complex flavors that evolve with age (from mild at 4–8 months to crystalline and caramelized at 24+ months).
#    - **Best for:** Cheese boards, grating, fondue, or eating plain.
#
# 2. **Roquefort** (AOP)
#    - **Why?** The "King of Blues"—creamy, tangy, and salty with a protected designation (made only from sheep’s milk in Roquefort-sur-Soulzon caves).
#    - **Best for:** Spread on bread, in salads, or with Sauternes wine.
#
# 3. **Camembert de Normandie** (AOP)
#    - **Why?** The quintessential French cheese—creamy, earthy, and buttery with a bloomy rind. Legendary since Napoleon’s time.
#    - **Best for:** Baked (Camembert en croûte), with apples or crusty bread.
#
# 4. **Époisses de Bourgogne** (AOP)
#    - **Why?** A pungent, washed-rind cheese with a luscious, almost liquid texture. Napoleon reportedly loved it.
#    - **Best for:** Bold flavor lovers; pair with Burgundy wine or champagne.
#
# 5. **Reblochon** (AOP)
#    - **Why?** The star of **tartiflette**—creamy, nutty, and slightly fruity with a washed rind.
#    - **Best for:** Melting (tartiflette, croque-monsieur) or on a platter.
#
# 6. **Brie de Meaux** (AOP)
#    - **Why?** The "Queen of Cheeses" (as declared at the Congress of Vienna in 1815). Rich, buttery, and mushroomy.
#    - **Best for:** Eating at room temperature with baguette or fruit.
#
# 7. **Munster (or Munster-Géromé)** (AOP)
#    - **Why?** A strong, smelly washed-rind cheese from Alsace with a creamy, almost meaty flavor.
#    - **Best for:** Pairing with Gewürztraminer or beer; great melted on potatoes.
#
# 8. **Chèvre (Goat Cheese) – Crottin de Chavignol, Valençay, or Sainte-Maure**
#    - **Why?** France’s goat cheeses range from fresh and tangy to aged and nutty. **Crottin de Chavignol** (AOP) is a standout—earthy and slightly acidic.
#    - **Best for:** Salads, baking, or spreading on toast.
#
# 9. **Beaufort** (AOP)
#    - **Why?** A firmer, richer cousin of Gruyère with floral and caramel notes. Often called the "Prince of Gruyères."
#    - **Best for:** Fondue, gratins, or shaving over dishes.
#
# 10. **Bleu d’Auvergne**
#    - **Why?** A creamy, spicy blue cheese with a more approachable funk than Roquefort.
#    - **Best for:** Dressings, burgers, or dessert with pears.
#
# ### **Honorable Mentions**
# - **Mimolette** (aged, nutty, and crumbly—like a French cheddar).
# - **Tomme de Savoie** (semi-firm, mild, and great for melting).
# - **Pont-l’Évêque** (square-shaped, buttery, and slightly salty).
# - **Banon** (goat cheese wrapped in chestnut leaves—earthy and creamy).
#
# ### **How to Choose?**
# - **Mild & Creamy?** Brie de Meaux, Camembert, or young Comté.
# - **Bold & Stinky?** Époisses, Munster, or Livarot.
# - **Nutty & Aged?** Old Comté, Beaufort, or Mimolette.
# - **Blue Cheese Lover?** Roquefort or Bleu d’Auvergne.
# - **Goat Cheese Fan?** Crottin de Chavignol or Valençay.
#
# ### **Pro Tip:**
# Visit a **fromagerie** (cheese shop) in France and ask for a **"plateau de fromages"** to sample a variety. Many shops will let you taste before buying!
#
# **Final Verdict:** If forced to pick *one* "best," **Comté** (for versatility) or **Roquefort** (for bold flavor) are top contenders—but the beauty of French cheese is in its diversity. Try them all!
#
# Would you like recommendations for pairings (wine, bread, fruit)?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most celebrated and iconic French cheeses, each with its own unique appeal:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Why?** A versatile, nutty, and slightly sweet Alpine cheese with complex flavors that evolve with age (from 4 months to 3+ years). Great for melting (fondue, croque-monsieur) or eating on its own.
#    - **Best for:** Everyday enjoyment, cooking, wine pairings (Chardonnay, Jura wines).
#
# 2. **Roquefort** (AOP)
#    - **Why?** The "King of Blues"—a rich, tangy, and creamy sheep’s milk blue cheese with a protected designation. Aged in the natural caves of Roquefort-sur-Soulzon.
#    - **Best for:** Bold flavor lovers, pairing with Sauternes or port, or crumbled over salads.
#
# 3. **Camembert de Normandie** (AOP)
#    - **Why?** The quintessential French cheese—creamy, buttery, and earthy with a bloomy rind. Legendary since Napoleon’s time.
#    - **Best for:** Baking (Camembert en croûte), spreading on bread, or pairing with Normandy cider.
#
# 4. **Époisses de Bourgogne** (AOP)
#    - **Why?** A pungent, runny, and intensely flavorful washed-rind cheese (washed in Marc de Bourgogne brandy). Napoleon reportedly loved it.
#    - **Best for:** Adventurous eaters, pairing with Burgundy wine, or spreading like butter.
#
# 5. **Reblochon** (AOP)
#    - **Why?** The star of **tartiflette**—creamy, nutty, and slightly funky with a washed rind. Made in the Alps.
#    - **Best for:** Melting (tartiflette, raclette), pairing with Savagnin wine.
#
# 6. **Brie de Meaux** (AOP)
#    - **Why?** The "Queen of Cheeses" (as declared at the Congress of Vienna in 1815). Buttery, mushroomy, and luxurious with a velvety rind.
#    - **Best for:** Cheese boards, pairing with Champagne, or baking.
#
# 7. **Munster (or Munster-Géromé)** (AOP)
#    - **Why?** A strong, smelly washed-rind cheese from Alsace with a creamy, mild interior. Often served with cumin.
#    - **Best for:** Pairing with Gewürztraminer, melting in tarts, or eating with potatoes.
#
# 8. **Beaufort** (AOP)
#    - **Why?** A firmer, sweeter Alpine cheese (like a refined Gruyère) with floral notes. Aged 6–24 months.
#    - **Best for:** Fondue, gratins, or eating with honey and nuts.
#
# 9. **Pélardon** (AOP)
#    - **Why?** A small, tangy goat cheese from the Cévennes or Provence, often coated in herbs or ash.
#    - **Best for:** Salads, pairing with rosé, or grilling.
#
# 10. **Fourme d’Ambert** (AOP)
#    - **Why?** A cylindrical blue cheese from Auvergne—milder and creamier than Roquefort, with a delicate mushroomy taste.
#    - **Best for:** Dessert cheese boards, pairing with sweet wines.
#
# ### **Honorable Mentions**
# - **Mimolette** (aged, nutty, and crumbly—like a French cheddar).
# - **Crottin de Chavignol** (tangy, firm goat cheese from the Loire).
# - **Tomme de Savoie** (semi-firm, mild, and great for melting).
# - **Banon** (goat cheese wrapped in chestnut leaves—earthy and creamy).
#
# ### **How to Choose?**
# - **For beginners:** Comté, Brie de Meaux, or young Camembert.
# - **For bold flavors:** Époisses, Roquefort, or Munster.
# - **For cooking:** Reblochon (tartiflette), Beaufort (fondue), or Comté (gratin).
# - **For wine pairings:** Époisses + Burgundy, Roquefort + Sauternes, Comté + Jura wine.
#
# ### **Final Verdict**
# If forced to pick **one** "best" cheese, **Comté** (aged 24+ months) might take the crown for its balance of complexity, versatility, and widespread appeal. But the true joy of French cheese is in the diversity—so explore!
#
# Would you like recommendations based on a specific dish or wine?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most **celebrated and iconic French cheeses**, each with its own unique character:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Type**: Hard, cooked pressed cheese (like Gruyère but nuttier).
#    - **Why it’s great**: Aged 4 months to 3+ years, with flavors ranging from buttery and mild to crystalline, caramelized, and complex. Perfect for melting (fondue, croque-monsieur) or eating on its own.
#    - **Best for**: Everyday eating, cooking, wine pairings (especially Jura wines).
#
# 2. **Roquefort** (AOP)
#    - **Type**: Blue cheese (sheep’s milk).
#    - **Why it’s great**: Creamy, tangy, and salty with a sharp blue mold. One of the oldest and most famous blue cheeses in the world.
#    - **Best for**: Bold flavor lovers, pairing with Sauternes (sweet wine) or walnuts.
#
# 3. **Camembert de Normandie** (AOP)
#    - **Type**: Soft, bloomy rind (cow’s milk).
#    - **Why it’s great**: Buttery, earthy, and slightly mushroomy when ripe. The quintessential French cheese, especially when oozing at room temperature.
#    - **Best for**: Baking (Camembert en croûte), spreading on bread, pairing with cider or Champagne.
#
# 4. **Époisses de Bourgogne** (AOP)
#    - **Type**: Washed-rind (cow’s milk).
#    - **Why it’s great**: Pungent, creamy, and intensely flavorful—often called the "king of cheeses" by Napoleon. Best eaten with a spoon when fully ripe.
#    - **Best for**: Adventurous eaters, pairing with Burgundy wine or baguette.
#
# 5. **Reblochon** (AOP)
#    - **Type**: Soft, washed rind (cow’s milk).
#    - **Why it’s great**: Rich, nutty, and slightly funky—essential for **tartiflette** (a melted cheese and potato dish).
#    - **Best for**: Alpine dishes, melting, pairing with white wine (like Savagnin).
#
# 6. **Brie de Meaux** (AOP)
#    - **Type**: Soft, bloomy rind (cow’s milk).
#    - **Why it’s great**: The "Queen of Cheeses," with a delicate, buttery, and slightly earthy flavor. Less intense than Camembert.
#    - **Best for**: Cheese boards, pairing with Champagne or Pinot Noir.
#
# 7. **Beaufort** (AOP)
#    - **Type**: Hard, cooked pressed (cow’s milk).
#    - **Why it’s great**: Similar to Gruyère but richer and fruitier, with a smooth, melt-in-your-mouth texture.
#    - **Best for**: Fondue, gratins, or eating in chunks with bread.
#
# 8. **Chèvre (Goat Cheese) – Crottin de Chavignol, Valençay, or Sainte-Maure**
#    - **Type**: Soft to semi-hard (goat’s milk).
#    - **Why it’s great**: Tangy, fresh, and versatile—ranging from creamy (young) to crumbly and sharp (aged).
#    - **Best for**: Salads, baking, or spreading on toast with honey.
#
# 9. **Mimolette**
#    - **Type**: Hard, aged (cow’s milk).
#    - **Why it’s great**: Bright orange, nutty, and slightly sweet with a crunchy texture (from cheese mites!). Often compared to aged Gouda.
#    - **Best for**: Snacking, grating over pasta, pairing with beer.
#
# 10. **Pont-l'Évêque**
#    - **Type**: Square-shaped, washed rind (cow’s milk).
#    - **Why it’s great**: Mild, buttery, and slightly salty—one of the oldest French cheeses (since the 12th century).
#    - **Best for**: Beginner-friendly, melting, or pairing with Normandy cider.
#
# ### **How to Choose the "Best" for You**
# - **Mild & Creamy?** → Brie de Meaux, Camembert, Saint-André.
# - **Bold & Funky?** → Époisses, Munster, Livarot.
# - **Nutty & Aged?** → Comté, Beaufort, Mimolette.
# - **Blue Cheese Lover?** → Roquefort, Bleu d’Auvergne.
# - **Goat Cheese Fan?** → Crottin de Chavignol, Valençay.
#
# ### **Fun Fact**
# France has **over 1,000 types of cheese**, and the famous quote (often misattributed to Charles de Gaulle) goes:
# *"How can you govern a country which has 246 varieties of cheese?"*
#
# ### **Final Verdict**
# If forced to pick **one** "best" all-around French cheese, **Comté** (aged 18+ months) is a crowd-pleaser—versatile, complex, and delicious in almost any form. But the true joy of French cheese is in the **diversity**, so explore and find your favorite!
#
# Would you like recommendations for pairings (wine, bread, etc.)?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted in a dish, or paired with wine). However, here are some of the most **iconic, beloved, and award-winning French cheeses**, each celebrated for its unique qualities:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Why?** A versatile, nutty, and slightly sweet **cooked pressed cheese** from the Jura mountains, aged 4 months to 3+ years. Perfect for melting (fondue, croque-monsieur) or eating on its own.
#    - **Best for:** Everyday eating, cooking, wine pairings (Chardonnay, Jura wines).
#
# 2. **Roquefort** (AOP)
#    - **Why?** The **king of blue cheeses**, made from sheep’s milk and aged in the natural caves of Roquefort-sur-Soulzon. Creamy, tangy, and intensely flavorful with a sharp saltiness.
#    - **Best for:** Bold cheese lovers, pairing with Sauternes or port.
#
# 3. **Époisses** (AOP)
#    - **Why?** A **pungent, creamy, washed-rind cow’s milk cheese** from Burgundy, often called the "stinkiest" (in a good way). Napoleon reportedly loved it.
#    - **Best for:** Adventurous eaters, spreading on bread, pairing with Burgundy Pinot Noir.
#
# 4. **Camembert de Normandie** (AOP)
#    - **Why?** The **quintessential French cheese**, buttery and earthy with a bloomy rind. Best when **runny** (ripe). The real deal is raw milk (lait cru).
#    - **Best for:** Classic cheese boards, baking (Camembert en croûte), pairing with Normandy cider.
#
# 5. **Reblochon** (AOP)
#    - **Why?** The **star of tartiflette**, a creamy, nutty, washed-rind cheese from the Alps. Melts beautifully.
#    - **Best for:** Alpine dishes, pairing with white wines like Roussette de Savoie.
#
# 6. **Brie de Meaux** (AOP)
#    - **Why?** The **"King of Cheeses"** (as declared at the Congress of Vienna in 1815). Rich, buttery, and mushroomy with a velvety rind.
#    - **Best for:** Luxurious cheese plates, pairing with Champagne.
#
# 7. **Beaufort** (AOP)
#    - **Why?** A **firm, fruity, and complex** Gruyère-style cheese from the Alps, aged 6–24 months. Often called the "Prince of Gruyères."
#    - **Best for:** Fondue, gratins, pairing with white Burgundy.
#
# 8. **Munster (Munster-Géromé)** (AOP)
#    - **Why?** A **strong, pungent washed-rind cheese** from Alsace, creamy and slightly smoky. Loved by Charles de Gaulle.
#    - **Best for:** Pairing with Gewürztraminer or beer, melting in tarts.
#
# 9. **Pélardon** (AOP)
#    - **Why?** A **small, tangy goat cheese** from the Cévennes or Provence, with a wrinkled rind and lemony kick.
#    - **Best for:** Salads, light meals, pairing with Sancerre.
#
# 10. **Fourme d’Ambert** (AOP)
#    - **Why?** A **mild, creamy blue cheese** from Auvergne, less salty than Roquefort, with a delicate mushroomy flavor.
#    - **Best for:** Blue cheese beginners, dessert pairings (with pears or honey).
#
# ### **Honorable Mentions**
# - **Cantalet** (AOP) – A firmer, salty cheese great for grating.
# - **Saint-Nectaire** (AOP) – Earthy and buttery, from Auvergne.
# - **Tomme de Savoie** – A rustic, semi-firm cheese with a gray rind.
# - **Banon** – A wrapped goat cheese from Provence, aged in chestnut leaves.
#
# ### **How to Choose?**
# - **For beginners:** Comté, Brie de Meaux, or Saint-Nectaire (mild and approachable).
# - **For bold flavors:** Époisses, Roquefort, or Munster.
# - **For cooking:** Comté (melting), Reblochon (tartiflette), or Cantalet (grating).
# - **For wine pairings:** Époisses (Burgundy), Roquefort (Sauternes), Brie (Champagne).
#
# ### **Final Verdict**
# If forced to pick **one "best"**, **Comté** (for versatility) or **Roquefort** (for intensity) often top lists. But the true answer? **Try them all!** France has over **1,000 cheeses**, so the best is the one you love most.
#
# Would you like recommendations based on a specific dish or wine?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most **iconic, beloved, and award-winning French cheeses**, each with its own unique character:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté (AOP)**
#    - **Type**: Hard, cooked pressed cheese (like Gruyère but nuttier).
#    - **Why it’s great**: Aged 4 months to 3+ years, with flavors ranging from buttery and mild to crystalline, caramelized, and complex. Perfect for melting (fondue, croque-monsieur) or eating on its own.
#    - **Best for**: Everyday eating, cooking, wine pairings (try with Jura wines).
#
# 2. **Roquefort (AOP)**
#    - **Type**: Blue cheese (sheep’s milk).
#    - **Why it’s great**: Creamy, tangy, and salty with a sharp blue mold. One of the world’s oldest blue cheeses, made in the caves of Roquefort-sur-Soulzon.
#    - **Best for**: Bold flavor lovers, salads, or spread on bread with honey.
#
# 3. **Époisses (AOP)**
#    - **Type**: Soft, washed-rind cow’s milk cheese.
#    - **Why it’s great**: Pungent, creamy, and decadent—Napoleon’s favorite! Washed in Marc de Bourgogne (brandy), it’s rich and spoonable when ripe.
#    - **Best for**: Cheese boards with crusty bread and Champagne.
#
# 4. **Camembert de Normandie (AOP)**
#    - **Type**: Soft, bloomy-rind cow’s milk cheese.
#    - **Why it’s great**: Buttery, earthy, and slightly mushroomy when ripe. The original Camembert (beware of industrial imitations).
#    - **Best for**: Baking (Camembert en croûte), pairing with cider or red wine.
#
# 5. **Reblochon (AOP)**
#    - **Type**: Soft, washed-rind cow’s milk cheese.
#    - **Why it’s great**: Creamy, nutty, and slightly fruity—essential for **tartiflette** (a melted cheese and potato dish).
#    - **Best for**: Alpine dishes, melting, or eating with charcuterie.
#
# 6. **Brie de Meaux (AOP)**
#    - **Type**: Soft, bloomy-rind cow’s milk cheese.
#    - **Why it’s great**: Rich, buttery, and slightly earthy—known as the "King of Cheeses" (Louis XIV loved it). Larger and more complex than standard Brie.
#    - **Best for**: Cheese plates, baking, or with truffles.
#
# 7. **Beaufort (AOP)**
#    - **Type**: Hard, cooked pressed cheese (like a refined Gruyère).
#    - **Why it’s great**: Sweet, nutty, and floral, with a smooth texture. Made in Alpine pastures.
#    - **Best for**: Fondue, gratins, or eating with fruit.
#
# 8. **Munster (AOP)**
#    - **Type**: Soft, washed-rind cow’s milk cheese.
#    - **Why it’s great**: Pungent, creamy, and slightly smoky—often served with cumin. A staple in Alsace.
#    - **Best for**: Melting on potatoes or pairing with Gewürztraminer.
#
# 9. **Chèvre (Goat Cheese) – Various (e.g., Crottin de Chavignol, Valençay, Selles-sur-Cher)**
#    - **Type**: Soft, semi-hard, or aged goat cheese.
#    - **Why it’s great**: Tangy, fresh, or nutty when aged. France has **hundreds** of artisanal goat cheeses.
#    - **Best for**: Salads, tarts, or spread on bread with fig jam.
#
# 10. **Fourme d’Ambert (AOP)**
#     - **Type**: Blue cheese (cow’s milk).
#     - **Why it’s great**: Milder and creamier than Roquefort, with a cylindrical shape.
#     - **Best for**: Beginners to blue cheese, dessert pairings.
#
# ### **Honorable Mentions**
# - **Pont-l’Évêque** (square-shaped, buttery Normandy cheese).
# - **Tomme de Savoie** (semi-hard, nutty Alpine cheese).
# - **Banon** (goat cheese wrapped in chestnut leaves).
# - **Mimolette** (vibrant orange, nutty, and crumbly—like a French cheddar).
#
# ### **How to Choose?**
# - **For beginners**: Comté, Brie de Meaux, or young Chèvre.
# - **For bold flavors**: Époisses, Roquefort, or Munster.
# - **For melting**: Reblochon, Beaufort, or Comté.
# - **For wine pairings**: Époisses (Burgundy), Roquefort (Sauternes), or Comté (Jura wines).
#
# ### **Final Verdict**
# If forced to pick **one "best"**, **Comté** (aged 24+ months) is a crowd-pleaser—versatile, complex, and universally loved. But the true joy of French cheese is in **exploring the diversity**—each region has its own masterpiece!
#
# **Pro Tip**: Visit a **fromagerie** (cheese shop) in France and ask for a **"plateau de fromages"** to sample a variety. And always let cheese sit at room temperature before eating!
#
# What’s your favorite way to enjoy cheese? 🧀🍷
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most celebrated and iconic French cheeses, each with its own unique charm:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Why?** A versatile, nutty, and slightly sweet Alpine cheese with complex flavors that evolve with aging (from 4 months to 3+ years). Great for melting, snacking, or pairing with wine.
#    - **Best for:** Fondue, gratins, charcuterie boards.
#
# 2. **Roquefort** (AOP)
#    - **Why?** The "King of Blues," made from sheep’s milk and aged in the natural caves of Roquefort-sur-Soulzon. Rich, tangy, and creamy with a sharp finish.
#    - **Best for:** Salads (like endive), on bread with honey, or in sauces.
#
# 3. **Camembert de Normandie** (AOP)
#    - **Why?** The quintessential French cheese—creamy, buttery, and earthy with a bloomy rind. Legendary since Napoleon III declared it his favorite.
#    - **Best for:** Baked (Camembert en croûte), with crusty bread, or apples.
#
# 4. **Époisses de Bourgogne** (AOP)
#    - **Why?** A pungent, washed-rind cheese with a luscious, almost liquid center. Napoleon called it the "King of Cheeses."
#    - **Best for:** Spreading on bread, pairing with Burgundy wine.
#
# 5. **Reblochon** (AOP)
#    - **Why?** The star of **tartiflette** (a baked potato and cheese dish). Creamy, nutty, and slightly fruity with a soft, washable rind.
#    - **Best for:** Melting in savory dishes.
#
# 6. **Brie de Meaux** (AOP)
#    - **Why?** Known as the "Cheese of Kings," this large-format Brie is buttery, mushroomy, and luxurious. A must for cheese platters.
#    - **Best for:** Pairing with Champagne or fruit.
#
# 7. **Munster (or Munster-Géromé)** (AOP)
#    - **Why?** A strong, smelly washed-rind cheese from Alsace with a creamy, mild interior. Often served with cumin.
#    - **Best for:** Melting in **tarte flambée** or on potatoes.
#
# 8. **Chèvre (Goat Cheese) – Crottin de Chavignol, Valençay, or Sainte-Maure**
#    - **Why?** France’s goat cheeses range from fresh and tangy to aged and crumbly. **Crottin de Chavignol** is a standout—nutty and slightly acidic.
#    - **Best for:** Salads, grilling, or spreading on toast.
#
# 9. **Beaufort** (AOP)
#    - **Why?** A firmer Alpine cheese similar to Gruyère but richer and fruitier. Often called the "Prince of Gruyères."
#    - **Best for:** Fondue, grilled cheese, or eating plain.
#
# 10. **Fourme d’Ambert** (AOP)
#    - **Why?** A cylindrical blue cheese milder than Roquefort, with a creamy texture and subtle mushroom notes.
#    - **Best for:** Dessert pairings (with pears or walnuts).
#
# ### **Honorable Mentions**
# - **Pont-l’Évêque** (square-shaped, buttery)
# - **Tomme de Savoie** (semi-firm, nutty)
# - **Bleu des Causses** (sheep’s milk blue, less salty than Roquefort)
# - **Chaource** (creamy, like a cross between Brie and Camembert)
#
# ### **How to Choose?**
# - **For beginners:** Start with **Comté (12–18 months)**, **Camembert**, or **Brie de Meaux**.
# - **For bold flavors:** Try **Époisses**, **Roquefort**, or **Munster**.
# - **For cooking:** **Reblochon** (tartiflette), **Comté** (gratin), or **Beaufort** (fondue).
# - **For goat cheese lovers:** **Crottin de Chavignol** or **Sainte-Maure**.
#
# ### **Fun Fact:**
# France has **over 1,000 cheeses**, and the famous quote (often misattributed to Charles de Gaulle) goes:
# *"How can you govern a country which has 246 varieties of cheese?"*
#
# Would you like recommendations based on a specific dish or wine pairing?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most **iconic, beloved, and award-winning French cheeses**, each celebrated for its unique qualities:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté (AOP)**
#    - **Why?** A versatile, nutty, and complex **hard cheese** from the Jura mountains, aged anywhere from 4 months to 3+ years. Younger Comté is mild and buttery; aged versions develop crystalline crunch and deep caramelized flavors.
#    - **Best for:** Cheese boards, grating, fondue, or eating plain.
#
# 2. **Roquefort (AOP)**
#    - **Why?** The **king of blue cheeses**, made from sheep’s milk and aged in the natural caves of Roquefort-sur-Soulzon. Creamy, tangy, and sharply salty with a luxurious melt-in-your-mouth texture.
#    - **Best for:** Spread on bread, in salads, or paired with Sauternes wine.
#
# 3. **Camembert de Normandie (AOP)**
#    - **Why?** The **quintessential French cheese**, creamy and earthy with a bloomy rind. When perfectly ripe, it’s gooey and rich; younger versions are milder.
#    - **Best for:** Baked (Camembert en croûte), on baguettes, or with apple cider.
#
# 4. **Époisses de Bourgogne (AOP)**
#    - **Why?** A **pungent, washed-rind** cheese with a velvety texture and a bold, barnyardy aroma. Napoleon reportedly loved it!
#    - **Best for:** Spreading on bread (it’s almost spoonable when ripe) or pairing with Burgundy wine.
#
# 5. **Reblochon (AOP)**
#    - **Why?** The star of **tartiflette** (a baked potato and cheese dish), this **creamy, nutty** Alpine cheese has a soft, supple texture and a hint of mushrooms.
#    - **Best for:** Melting (tartiflette, croque-monsieur) or on a cheese plate.
#
# 6. **Brie de Meaux (AOP)**
#    - **Why?** The **"King of Cheeses"** (as declared at the Congress of Vienna in 1815), this **buttery, mushroomy** Brie is richer and more complex than industrial versions.
#    - **Best for:** Eating with champagne, on crackers, or baked.
#
# 7. **Munster (AOP)**
#    - **Why?** A **strong, smelly** washed-rind cheese from Alsace, with a creamy interior and a distinct orange rind. Less aggressive than Époisses but still bold.
#    - **Best for:** Melting (in tarts or on potatoes) or with Gewürztraminer wine.
#
# 8. **Beaufort (AOP)**
#    - **Why?** A **firm, fruity** Alpine cheese similar to Gruyère but nuttier and more refined. Aged versions develop caramel notes.
#    - **Best for:** Fondue, grating over dishes, or eating in chunks.
#
# 9. **Pélardon**
#    - **Why?** A **small, tangy goat cheese** from the Cévennes or Provence, with a wrinkled rind and a bright, citrusy flavor.
#    - **Best for:** Salads, on toast, or with honey and nuts.
#
# 10. **Fourme d’Ambert (AOP)**
#    - **Why?** A **mild, creamy blue cheese** with a cylindrical shape, less salty than Roquefort but still rich and slightly sweet.
#    - **Best for:** Dessert plates, with pears, or in sauces.
#
# ### **Honorable Mentions**
# - **Cantalet** (a firmer, cheaper alternative to Comté)
# - **Saint-Nectaire** (a semi-soft, earthy cow’s milk cheese)
# - **Crottin de Chavignol** (a dry, intense goat cheese)
# - **Mimolette** (a vibrant orange, nutty hard cheese)
# - **Tomme de Savoie** (a rustic, mild Alpine cheese)
#
# ### **How to Choose?**
# - **For beginners:** Comté, Brie de Meaux, or young Camembert.
# - **For bold flavors:** Roquefort, Époisses, or Munster.
# - **For melting:** Reblochon, Beaufort, or Comté.
# - **For goat cheese lovers:** Pélardon or Crottin de Chavignol.
#
# ### **Fun Fact:**
# France has **over 1,000 types of cheese**, and the famous quote (often misattributed to Charles de Gaulle) goes:
# *"How can you govern a country which has 246 varieties of cheese?"*
#
# **Final Verdict?** If forced to pick **one** "best" cheese, **Comté** (for its versatility) or **Roquefort** (for its unmatched depth) would be top contenders—but the beauty of French cheese is in its diversity!
#
# Would you like recommendations based on a specific dish or wine pairing?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, in cooking, with wine, etc.). However, here are some of the most celebrated and iconic French cheeses, each with its own unique appeal:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Why?** A versatile, nutty, and slightly sweet Alpine cheese with complex flavors that evolve with age (from 4 months to 3+ years). Great for melting (fondue, croque-monsieur) or eating on its own.
#    - **Best for:** Everyday eating, cooking, wine pairings (Chardonnay, Jura wines).
#
# 2. **Roquefort** (AOP)
#    - **Why?** The "King of Blues," made from sheep’s milk and aged in the natural caves of Roquefort-sur-Soulzon. Creamy, tangy, and intensely flavorful with a sharp, salty bite.
#    - **Best for:** Bold cheese lovers, pairing with Sauternes or port, or crumbled over salads.
#
# 3. **Camembert de Normandie** (AOP)
#    - **Why?** The quintessential French cheese—creamy, buttery, and earthy with a bloomy rind. Legendary since Napoleon III declared it his favorite.
#    - **Best for:** Baking (Camembert en croûte), spreading on bread, pairing with Normandy cider or light reds.
#
# 4. **Époisses de Bourgogne** (AOP)
#    - **Why?** A pungent, washed-rind cheese with a luscious, almost liquid center. Napoleon called it the "King of Cheeses." Strong aroma but rich, savory-sweet taste.
#    - **Best for:** Adventurous eaters, pairing with Burgundy wines (Pinot Noir).
#
# 5. **Reblochon** (AOP)
#    - **Why?** The star of **tartiflette** (a melted cheese and potato dish), this cow’s milk cheese is creamy, nutty, and slightly fruity with a soft, washable rind.
#    - **Best for:** Alpine dishes, melting, pairing with Savagnin or Beaujolais.
#
# 6. **Brie de Meaux** (AOP)
#    - **Why?** The "Queen of Cheeses," a luxurious triple-créme with a velvety texture and mild, mushroomy flavor. Often served at grand occasions.
#    - **Best for:** Cheese boards, pairing with Champagne or Chablis.
#
# 7. **Munster (Munster-Géromé)** (AOP)
#    - **Why?** A washed-rind cheese from Alsace with a strong smell but mild, creamy, and slightly tangy taste. Often served with cumin.
#    - **Best for:** Pairing with Gewürztraminer or beer, melting in tarts.
#
# 8. **Beaufort** (AOP)
#    - **Why?** A firmer, buttery Alpine cheese similar to Gruyère but richer and nuttier. Aged versions develop crystalline crunch.
#    - **Best for:** Fondue, gratins, pairing with white Burgundy.
#
# 9. **Crottin de Chavignol** (AOP)
#    - **Why?** A small, tangy goat cheese from the Loire Valley. Young versions are fresh and lemony; aged ones are dense and nutty.
#    - **Best for:** Salads (like **Selle sur Cher**), pairing with Sancerre.
#
# 10. **Bleu d’Auvergne**
#    - **Why?** A creamy, spicy blue cheese with a sharper taste than Roquefort but less crumbly. Made with cow’s milk.
#    - **Best for:** Dressings, burgers, pairing with sweet wines (Monbazillac).
#
# ### **Honorable Mentions**
# - **Pont-l’Évêque** (square-shaped, buttery Norman cheese)
# - **Tomme de Savoie** (semi-firm, nutty Alpine cheese)
# - **Pélardon** (small, tangy goat cheese from the Cévennes)
# - **Mimolette** (vibrant orange, nutty, and slightly sweet—like a French cheddar)
#
# ### **How to Choose?**
# - **Mild & Creamy:** Brie, Camembert, Saint-André
# - **Bold & Pungent:** Époisses, Munster, Livarot
# - **Nutty & Firm:** Comté, Beaufort, Cantal
# - **Blue Cheeses:** Roquefort, Bleu d’Auvergne, Fourme d’Ambert
# - **Goat Cheeses:** Crottin, Valençay, Rocamadour
#
# ### **The Ultimate Answer?**
# If forced to pick **one** "best" cheese, **Comté** (aged 24+ months) is a crowd-pleaser for its depth and versatility, while **Roquefort** and **Époisses** reign for bold flavors. But the beauty of French cheese is its diversity—try a mix!
#
# **Pro Tip:** Visit a **fromagerie** in France (like **Laurent Dubois** in Paris) for expert recommendations and tastings. And always serve cheese at room temperature!
#
# What’s your favorite way to enjoy cheese—on a board, melted, or in a dish?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, in cooking, with wine, etc.). However, here are some of the most celebrated and iconic French cheeses, each with its own unique character:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Type**: Hard, cooked pressed cheese (like Gruyère but nuttier).
#    - **Why it’s great**: Aged 4 months to 3+ years, with flavors ranging from buttery and mild to crystalline, caramelized, and complex. Perfect for melting (fondue, croque-monsieur) or eating on its own.
#    - **Best with**: Walnuts, honey, or a glass of Jura wine.
#
# 2. **Roquefort** (AOP)
#    - **Type**: Blue cheese (sheep’s milk).
#    - **Why it’s great**: Creamy, tangy, and salty with a sharp blue veining. One of the world’s oldest blue cheeses, made in the caves of Roquefort-sur-Soulzon.
#    - **Best with**: Pears, fig jam, or Sauternes (sweet wine).
#
# 3. **Camembert de Normandie** (AOP)
#    - **Type**: Soft, bloomy rind (cow’s milk).
#    - **Why it’s great**: Rich, buttery, and earthy when ripe (runny center!). The original Camembert is a French icon, especially when baked (*Camembert au four*).
#    - **Best with**: Crusty bread, apples, or Normandy cider.
#
# 4. **Époisses de Bourgogne** (AOP)
#    - **Type**: Washed-rind (cow’s milk).
#    - **Why it’s great**: Pungent, creamy, and intensely flavorful—Napoleon’s favorite! The rind is washed in Marc de Bourgogne (brandy), giving it a bold aroma.
#    - **Best with**: Champagne or a Burgundy red wine.
#
# 5. **Reblochon** (AOP)
#    - **Type**: Soft, washed-rind (cow’s milk).
#    - **Why it’s great**: Nutty, creamy, and slightly funky—essential for *tartiflette* (a baked potato and cheese dish).
#    - **Best with**: White wine (like Savagnin) or potatoes.
#
# 6. **Brie de Meaux** (AOP)
#    - **Type**: Soft, bloomy rind (cow’s milk).
#    - **Why it’s great**: The "King of Cheeses" (as declared at the Congress of Vienna in 1815). Buttery, mushroomy, and luxurious when perfectly ripe.
#    - **Best with**: Baguette, grapes, or Champagne.
#
# 7. **Beaufort** (AOP)
#    - **Type**: Hard, cooked pressed (cow’s milk, Alpine).
#    - **Why it’s great**: Similar to Gruyère but sweeter and fruitier, with a smooth, firm texture. Excellent for fondues or grating over dishes.
#    - **Best with**: White wine (like Chignin) or charcuterie.
#
# 8. **Munster (or Munster-Géromé)** (AOP)
#    - **Type**: Washed-rind (cow’s milk).
#    - **Why it’s great**: Pungent, creamy, and slightly smoky—traditionally served with cumin. A staple in Alsace.
#    - **Best with**: Riesling or Gewürztraminer.
#
# 9. **Chèvre (Goat Cheese)**
#    - **Types**: Fresh (*Bûche de Chèvre*), aged (*Crottin de Chavignol*), or ash-coated (*Sainte-Maure de Touraine*).
#    - **Why it’s great**: Tangy, bright, and versatile. Young chèvre is mild; aged versions are crumbly and intense.
#    - **Best with**: Herbs, beetroot, or Sancerre (Loire Valley white).
#
# 10. **Bleu d’Auvergne** (AOP)
#     - **Type**: Blue cheese (cow’s milk).
#     - **Why it’s great**: Creamier and less salty than Roquefort, with a spicy kick. Great for sauces or salads.
#     - **Best with**: Sweet wines (like Monbazillac) or walnuts.
#
# ### **How to Choose?**
# - **For beginners**: Comté (mild), Brie de Meaux, or fresh Chèvre.
# - **For bold flavors**: Époisses, Roquefort, or Munster.
# - **For cooking**: Beaufort (grating), Reblochon (tartiflette), or Comté (fondue).
# - **For a cheese board**: A mix of textures (e.g., Comté + Brie + Blue + Chèvre).
#
# ### **Fun Fact**
# France has over **1,000 types of cheese**, and the famous quote (often misattributed to Charles de Gaulle) goes:
# *"How can you govern a country which has 246 varieties of cheese?"*
#
# **Final Verdict?** There’s no single "best"—explore and find your favorite! If forced to pick one, **Comté** (for versatility) or **Époisses** (for sheer indulgence) are top contenders.
#
# Would you like recommendations based on a specific dish or wine pairing?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, in cooking, with wine, etc.). However, here are some of the most celebrated and iconic French cheeses, each with its own unique appeal:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Why?** A versatile, nutty, and slightly sweet Alpine cheese with complex flavors that evolve with age (from mild at 4–8 months to crystalline and caramelized at 24+ months).
#    - **Best for:** Cheese boards, fondue, grating over dishes, or eating plain with bread and wine.
#    - **Pair with:** White Burgundy, Jura wines, or a crisp Chablis.
#
# 2. **Roquefort** (AOP)
#    - **Why?** The "King of Blues"—creamy, tangy, and salty with a protected designation (made only from sheep’s milk in Roquefort-sur-Soulzon’s caves).
#    - **Best for:** Spread on baguettes, in salads, or with pears and walnuts.
#    - **Pair with:** Sauternes (sweet wine) or a bold red like Cahors.
#
# 3. **Époisses de Bourgogne** (AOP)
#    - **Why?** A pungent, runny, washed-rind cheese with a powerful aroma (Napoleon’s favorite!). Rich, meaty, and buttery.
#    - **Best for:** Brave cheese lovers—spread on bread or paired with champagne.
#    - **Pair with:** Burgundy Pinot Noir or a fruity Beaujolais.
#
# 4. **Camembert de Normandie** (AOP)
#    - **Why?** The quintessential French cheese—creamy, earthy, and slightly mushroomy when ripe. Best when oozing at room temperature.
#    - **Best for:** Baked (Camembert en croûte), with apples, or on a rustic baguette.
#    - **Pair with:** Norman cider or a light red like Pinot Noir.
#
# 5. **Reblochon** (AOP)
#    - **Why?** The star of **tartiflette**—creamy, nutty, and slightly smoky with a soft, wash-rind exterior.
#    - **Best for:** Melting in dishes or enjoying with charcuterie.
#    - **Pair with:** Savagnin (Jura wine) or a crisp white like Jacquère.
#
# 6. **Brie de Meaux** (AOP)
#    - **Why?** The "Queen of Cheeses" (as declared by Talleyrand at the Congress of Vienna). Buttery, mild, and slightly earthy.
#    - **Best for:** Cheese plates, baked Brie, or with truffles.
#    - **Pair with:** Champagne or a light red like Gamay.
#
# 7. **Munster (Munster-Géromé)** (AOP)
#    - **Why?** A stinky, orange-rind cheese from Alsace with a creamy, mild interior. Less aggressive than Époisses but still bold.
#    - **Best for:** Melting in **tarte flambée** or with cumquats.
#    - **Pair with:** Gewürztraminer or a hoppy Alsace beer.
#
# 8. **Beaufort** (AOP)
#    - **Why?** A firmer, buttery Alpine cheese (like a refined Gruyère) with floral and fruity notes.
#    - **Best for:** Fondue, grating, or eating in chunks.
#    - **Pair with:** White Burgundy or a nutty Jura wine.
#
# 9. **Pélardon** (AOP)
#    - **Why?** A small, tangy goat cheese from the Cévennes or Provence, ranging from fresh and lemony to aged and crumbly.
#    - **Best for:** Salads, on toast, or with honey and nuts.
#    - **Pair with:** Sancerre or a rosé from Provence.
#
# 10. **Bleu d’Auvergne**
#    - **Why?** A creamy, spicy blue cheese (less intense than Roquefort) with a velvety texture.
#    - **Best for:** Sauces, burgers, or dessert with figs.
#    - **Pair with:** Port or a sweet Monbazillac.
#
# ### **Honorable Mentions**
# - **Mimolette** (vibrant orange, nutty, and crumbly—like a French cheddar).
# - **Crottin de Chavignol** (tiny, tangy goat cheese from the Loire).
# - **Tomme de Savoie** (semi-firm, mild, and great for melting).
# - **Banon** (goat cheese wrapped in chestnut leaves—earthy and creamy).
#
# ### **How to Choose?**
# - **Mild & Creamy?** Brie de Meaux, Camembert, Saint-André.
# - **Bold & Stinky?** Époisses, Munster, Pont-l’Évêque.
# - **Nutty & Aged?** Comté, Beaufort, Mimolette.
# - **Blue Cheese Lover?** Roquefort, Bleu d’Auvergne, Fourme d’Ambert.
# - **Goat Cheese Fan?** Crottin, Pélardon, Banon.
#
# ### **Final Verdict**
# If forced to pick **one** "best" cheese, **Comté** (aged 18–24 months) is a crowd-pleaser for its balance of complexity and versatility. But for sheer indulgence, **Époisses** or **Roquefort** are unforgettable.
#
# **Pro Tip:** Visit a **fromagerie** in France (like **Laurent Dubois** in Paris) to taste before buying—cheese is best enjoyed fresh and at the perfect ripeness!
#
# What’s your favorite way to enjoy French cheese? With wine, bread, or in a dish?
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most **iconic, beloved, and award-winning French cheeses**, each celebrated for its unique qualities:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Why?** A versatile, nutty, and complex **alpine cheese** aged 4 months to 3+ years. Younger Comté is mild and buttery; aged versions develop crystalline crunch and deep caramelized flavors.
#    - **Best for:** Cheese boards, fondue, grilled cheese, or eating plain.
#    - **Fun fact:** Made in the Jura Mountains, each wheel is unique based on the terroir and aging.
#
# 2. **Roquefort** (AOP)
#    - **Why?** The **king of blue cheeses**, made from sheep’s milk and aged in natural caves in Roquefort-sur-Soulzon. Creamy, tangy, and sharply salty with a luxurious melt-in-your-mouth texture.
#    - **Best for:** Spread on bread with honey or pear, in salads, or sauces.
#    - **Fun fact:** One of the oldest cheeses in the world (mentioned by Pliny the Elder in 79 AD).
#
# 3. **Époisses de Bourgogne** (AOP)
#    - **Why?** A **pungent, runny, washed-rind cow’s milk cheese** with a bold, barnyardy aroma and rich, buttery-sweet flavor. Napoleon reportedly loved it.
#    - **Best for:** Spreading on crusty bread or pairing with Burgundy wine.
#    - **Warning:** So strong it’s banned on French public transport!
#
# 4. **Camembert de Normandie** (AOP)
#    - **Why?** The **quintessential French cheese**, creamy and earthy with a bloomy rind. Best when perfectly ripe (soft but not liquid).
#    - **Best for:** Baked (Camembert en croûte), with apples, or in sandwiches.
#    - **Fun fact:** Legend says it was first made by Marie Harel during the French Revolution.
#
# 5. **Reblochon** (AOP)
#    - **Why?** The **star of tartiflette** (a melted cheese and potato dish), this cow’s milk cheese is buttery, nutty, and slightly mushroomy.
#    - **Best for:** Melting (tartiflette, croque-monsieur) or on a charcuterie board.
#    - **Fun fact:** Monks originally made it in the Alps—its name means "re-bloom" (from the cows’ second milking).
#
# 6. **Brie de Meaux** (AOP)
#    - **Why?** The **"King of Cheeses"** (as declared at the Congress of Vienna in 1815), this large-wheel Brie is richer and more complex than industrial Brie. Creamy, earthy, and slightly mushroomy.
#    - **Best for:** Pairing with Champagne or fruit (grapes, figs).
#    - **Fun fact:** Louis XVI’s last meal request was Brie before his execution.
#
# 7. **Munster (or Munster-Géromé)** (AOP)
#    - **Why?** A **stinky, washed-rind cow’s milk cheese** from Alsace, with a supple texture and a balance of funk and sweetness.
#    - **Best for:** Melting (in tarte flambée) or with cumin and potatoes.
#    - **Fun fact:** Monks originally made it in monasteries ("Munster" comes from "monastère").
#
# 8. **Pélardon** (AOP)
#    - **Why?** A **small, tangy goat cheese** from the Cévennes or Provence, with a wrinkled rind and a bright, lemony flavor.
#    - **Best for:** Salads, grilling, or spreading on toast.
#    - **Fun fact:** One of the oldest French cheeses, dating back to Roman times.
#
# 9. **Beaufort** (AOP)
#    - **Why?** A **firm, nutty alpine cheese** similar to Gruyère but richer and fruitier. Aged versions develop caramelized notes.
#    - **Best for:** Fondue, gratins, or shaving over salads.
#    - **Fun fact:** Made in the Beaufortain valley, where cows graze on wildflowers.
#
# 10. **Crottin de Chavignol** (AOP)
#    - **Why?** A **dry, crumbly goat cheese** with a sharp, citrusy tang. Can be young (soft) or aged (hard and nutty).
#    - **Best for:** Salads (like the classic *Crottin chaud*), baking, or with Sancerre wine.
#
# ### **Honorable Mentions**
# - **Saint-Nectaire** (AOP) – Earthy, semi-soft cow’s milk cheese from Auvergne.
# - **Tomme de Savoie** – A rustic, mild alpine cheese great for melting.
# - **Banon** – A wrapped goat cheese from Provence, aged in chestnut leaves.
# - **Mimolette** – A bright orange, nutty hard cheese (like a French cheddar).
# - **Pont-l’Évêque** – A square, buttery cow’s milk cheese from Normandy.
#
# ### **How to Choose?**
# - **Mild & creamy?** Comté, Brie de Meaux, Saint-Nectaire.
# - **Strong & stinky?** Époisses, Munster, Livarot.
# - **Blue cheese lover?** Roquefort, Bleu d’Auvergne.
# - **Goat cheese fan?** Crottin, Pélardon, Banon.
# - **Melting cheese?** Reblochon, Beaufort, Tomme de Savoie.
#
# ### **Final Verdict**
# If forced to pick **one "best"**, **Comté** (for its versatility and depth) or **Roquefort** (for its unmatched boldness) would top many lists. But the beauty of French cheese is its **diversity**—each region and milk type (cow, goat, sheep) offers something unique.
#
# **Pro tip:** Visit a *fromagerie* in France and ask for a *plateau de fromages* to taste several! And always serve cheese at room temperature for the best flavor.
#
# What’s your favorite? 😊🧀
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most **iconic, beloved, and award-winning French cheeses**, each celebrated for its unique qualities:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté (AOP)**
#    - **Why?** A versatile, nutty, and complex **raw cow’s milk** cheese from the Jura mountains, aged 4 months to 3+ years. Younger Comté is mild and buttery; aged versions develop crystalline crunch and deep caramelized flavors.
#    - **Best for:** Cheese boards, grating, fondue, or eating solo.
#    - **Award:** Often wins at the **World Cheese Awards** (e.g., 2021–2022 gold medals).
#
# 2. **Roquefort (AOP)**
#    - **Why?** The **king of blue cheeses**, made from **raw sheep’s milk** and aged in the natural caves of Roquefort-sur-Soulzon. Creamy, tangy, and sharply salty with a lingering spice.
#    - **Best for:** Spread on bread, in salads, or with Sauternes wine.
#    - **Fun fact:** Protected by law since **1411**—one of the oldest AOP cheeses.
#
# 3. **Époisses (AOP)**
#    - **Why?** A **pungent, runny, washed-rind** cow’s milk cheese from Burgundy, washed in **Marc de Bourgogne** (brandy). Napoleon reportedly loved it.
#    - **Best for:** Bold cheese lovers; pair with Champagne or Pinot Noir.
#    - **Warning:** So strong it’s **banned on French public transport**!
#
# 4. **Camembert de Normandie (AOP)**
#    - **Why?** The **quintessential French cheese**, creamy and earthy with a bloomy rind. Best when **runny at room temperature**.
#    - **Best for:** Baked (Camembert en croûte), with apples or crusty bread.
#    - **Tip:** Look for **raw milk** versions (e.g., **Camembert Le Châtelain**).
#
# 5. **Reblochon (AOP)**
#    - **Why?** The **star of tartiflette**, a washed-rind cheese from the Alps with a **buttery, slightly funky** flavor. Melts like a dream.
#    - **Best for:** Tartiflette, raclette, or on a platter with charcuterie.
#
# 6. **Brie de Meaux (AOP)**
#    - **Why?** The **"King of Cheeses"** (as declared at the 1815 Congress of Vienna), richer and more complex than generic Brie. Earthy, mushroomy, and creamy.
#    - **Best for:** With truffles, on a baguette, or baked.
#
# 7. **Munster (AOP)**
#    - **Why?** A **stinky, supple** cow’s milk cheese from Alsace, washed in brine or beer. Pungent aroma but **mild, buttery taste**.
#    - **Best for:** Melting (great in **tarte flambée**), with cumin or potatoes.
#
# 8. **Beaufort (AOP)**
#    - **Why?** A **firm, nutty, Gruyère-like** cheese from the Alps, made with **summer milk** (best quality). Less holey than Swiss cheeses, with a **sweet, caramelized** finish.
#    - **Best for:** Fondue, grating, or eating in chunks.
#
# 9. **Picodon (AOP)**
#    - **Why?** A **small, tangy goat cheese** from the Rhône-Alpes, aged to perfection (young = creamy; aged = crumbly and sharp).
#    - **Best for:** Salads, on toast, or with honey.
#
# 10. **Bleu d’Auvergne (AOP)**
#    - **Why?** A **creamy, spicy blue** cheese (less intense than Roquefort), made with cow’s milk. Great for blue cheese beginners.
#    - **Best for:** Burgers, sauces, or with pears.
#
# ### **Honorable Mentions**
# - **Saint-Nectaire** (AOP) – Earthy, semi-soft cow’s milk cheese.
# - **Crottin de Chavignol** – Aged goat cheese (amazing grilled).
# - **Tomme de Savoie** – Rustic, mild alpine cheese.
# - **Mimolette** – Bright orange, nutty, and crumbly (like a French cheddar).
#
# ### **How to Choose?**
# - **Mild & creamy?** Comté, Brie de Meaux, Saint-Nectaire.
# - **Strong & stinky?** Époisses, Munster, Pont-l’Évêque.
# - **Blue cheese?** Roquefort (sheep) or Bleu d’Auvergne (cow).
# - **Melting?** Reblochon, Beaufort, Raclette.
# - **Goat cheese?** Crottin, Picodon, Sainte-Maure.
#
# ### **Pro Tip:**
# For the **ultimate French cheese experience**, visit a **fromagerie** (cheese shop) in France and ask for:
# - **"Un plateau de fromages affiné"** (a board of aged cheeses).
# - **"Quels sont vos fromages à pâte persillée?"** (What blue cheeses do you have?).
# - **"Un fromage de chèvre crémeux, s’il vous plaît"** (A creamy goat cheese, please).
#
# Would you like recommendations based on a specific dish or wine pairing? 😊
# ---------------------------------------------------------------------------
# SDKError                                  Traceback (most recent call last)
# Cell In[22], line 9
#       6 doc_copy = doc.copy()
#       7 doc_content = doc_copy.pop('content')
# ----> 9 sections = intelligent_chunking(doc_content)
#      10 for section in sections:
#      11     section_doc = doc_copy.copy()
#
# Cell In[21], line 3, in intelligent_chunking(text)
#       1 def intelligent_chunking(text):
#       2     prompt = prompt_template.format(document=text)
# ----> 3     response = llm(prompt)
#       4     sections = response.split('---')
#       5     sections = [s.strip() for s in sections if s.strip()]
#
# Cell In[20], line 11, in llm(prompt, model)
#      10 def llm(prompt, model="mistral-large-latest"):
# ---> 11     chat_response = client.chat.complete(
#      12         model= model,
#      13         messages = [
#      14             {
#      15                 "role": "user",
#      16                 "content": "What is the best French cheese?",
#      17             },
#      18         ]
#      19     )
#      20     print(chat_response.choices[0].message.content)
#      21     return chat_response.choices[0].message.content
#
# File ~/Documents/GitHub/ai_agent_crash_course/aihero/Day_2/.venv/lib/python3.12/site-packages/mistralai/chat.py:247, in Chat.complete(self, model, messages, temperature, top_p, max_tokens, stream, stop, random_seed, response_format, tools, tool_choice, presence_penalty, frequency_penalty, n, prediction, parallel_tool_calls, prompt_mode, safe_prompt, retries, server_url, timeout_ms, http_headers)
#     245 if utils.match_response(http_res, "4XX", "*"):
#     246     http_res_text = utils.stream_to_text(http_res)
# --> 247     raise models.SDKError(
#     248         "API error occurred", http_res.status_code, http_res_text, http_res
#     249     )
#     250 if utils.match_response(http_res, "5XX", "*"):
#     251     http_res_text = utils.stream_to_text(http_res)
#
# SDKError: API error occurred: Status 429
# {"object":"error","message":"Service tier capacity exceeded for this model.","type":"service_tier_capacity_exceeded","param":null,"code":"3505"}
